# %%
#Importamos las librerias 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score


#Cargamos el dataset y mostramos las 5 primeras filas
data = pd.read_csv("C:/Users/usuario/ANALISIS DE DATOS/winequality-red.csv")
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
# 5            7.4              0.66         0.00             1.8      0.075
# 6            7.9              0.60         0.06             1.6      0.069
# 7            7.3              0.65         0.00             1.2      0.065
# 8            7.8              0.58         0.02             2.0      0.073
# 9            7.5              0.50         0.36             6.1      0.071
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
#Descripcion de los datos
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
#encontrar valores nulos
data.isna().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# grafica sobre distribución de los datos
plt.hist(data.alcohol)
# Out:
# (array([ 37., 515., 323., 257., 232., 119.,  87.,  21.,   7.,   1.]),
#  array([ 8.4 ,  9.05,  9.7 , 10.35, 11.  , 11.65, 12.3 , 12.95, 13.6 ,
#         14.25, 14.9 ]),
#  <BarContainer object of 10 artists>)

# %%
#Diagarama de dispersion de tres datos
sns.scatterplot(x = "alcohol", y = "sulphates", hue = "quality", data = data)
# Out:
# <Axes: xlabel='alcohol', ylabel='sulphates'>

# %%
#variables para la prediccion
predictors_col = ["fixed acidity", "volatile acidity", "citric acid", "residual sugar", "chlorides", "free sulfur dioxide", "total sulfur dioxide", "density", "pH", "sulphates", "alcohol"]
target_col = ['quality']

predictors = data[predictors_col]
target = data[target_col]

#ejecucion de resultados
predictors
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
#ejecucion de resultados
target
# Out:
#       quality
# 0           5
# 1           5
# 2           5
# 3           6
# 4           5
# ...       ...
# 1594        5
# 1595        6
# 1596        6
# 1597        5
# 1598        6
#
# [1599 rows x 1 columns]

# %%
# la correlación de las columnas del dataset
corr = predictors.corr()
corr
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.256131     0.671703
# volatile acidity          -0.256131          1.000000    -0.552496
# citric acid                0.671703         -0.552496     1.000000
# residual sugar             0.114777          0.001918     0.143577
# chlorides                  0.093705          0.061298     0.203823
# free sulfur dioxide       -0.153794         -0.010504    -0.060978
# total sulfur dioxide      -0.113181          0.076470     0.035533
# density                    0.668047          0.022026     0.364947
# pH                        -0.682978          0.234937    -0.541904
# sulphates                  0.183006         -0.260987     0.312770
# alcohol                   -0.061668         -0.202288     0.109903
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# fixed acidity               0.114777   0.093705            -0.153794
# ...

# %%
#mapa de calor sobre la correlacion de las columnas
sns.heatmap(corr)
plt.show()

# %%
#Finalizacion de el análisis gde datos, se procede a la ejecucion del modelo, se toma 25% para datos de test
X_train, X_test, y_train, y_test = train_test_split(predictors, target, test_size=0.25, random_state=13)

#se crea arbol de desision
tree = DecisionTreeClassifier()

#se entrana arbol de desición
arbol = tree.fit(X_train, y_train)

# ver el arbol
plot_tree(arbol)
# Out:
# [Text(0.47863230579852434, 0.9791666666666666, 'x[10] <= 10.525\ngini = 0.644\nsamples = 1199\nvalue = [8, 42, 500, 487, 150, 12]'),
#  Text(0.22841777118291087, 0.9375, 'x[9] <= 0.535\ngini = 0.542\nsamples = 725\nvalue = [5, 27, 423, 246, 24, 0]'),
#  Text(0.03879566821373319, 0.8958333333333334, 'x[1] <= 0.335\ngini = 0.369\nsamples = 173\nvalue = [2, 13, 135, 22, 1, 0]'),
#  Text(0.020944900630727122, 0.8541666666666666, 'x[2] <= 0.43\ngini = 0.54\nsamples = 10\nvalue = [0, 1, 3, 6, 0, 0]'),
#  Text(0.017136736879685827, 0.8125, 'x[9] <= 0.485\ngini = 0.56\nsamples = 5\nvalue = [0, 1, 3, 1, 0, 0]'),
#  Text(0.013328573128644532, 0.7708333333333334, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3, 0, 0, 0]'),
#  Text(0.020944900630727122, 0.7708333333333334, 'x[6] <= 33.0\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 1, 0, 0]'),
#  Text(0.017136736879685827, 0.7291666666666666, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0]'),
# ...

# %%
#se hacen las predicciones del 20% restante
predicciones = arbol.predict(X_test)

predicciones
# Out:
# array([7, 5, 5, 5, 6, 5, 6, 7, 5, 5, 5, 6, 5, 6, 7, 7, 6, 7, 5, 7, 5, 6,
#        7, 5, 6, 7, 5, 5, 5, 7, 6, 5, 5, 6, 5, 6, 5, 6, 6, 7, 5, 5, 6, 6,
#        5, 5, 6, 6, 6, 6, 7, 5, 6, 5, 7, 5, 5, 6, 6, 5, 5, 7, 5, 5, 7, 7,
#        6, 7, 5, 5, 6, 5, 7, 6, 5, 5, 5, 5, 5, 5, 6, 6, 6, 5, 6, 5, 7, 6,
#        6, 6, 6, 6, 7, 7, 5, 6, 6, 6, 6, 5, 7, 6, 5, 5, 7, 5, 5, 6, 5, 7,
#        7, 8, 6, 6, 5, 6, 6, 7, 5, 7, 7, 5, 5, 6, 5, 6, 5, 5, 6, 7, 6, 5,
#        6, 7, 5, 5, 7, 5, 6, 7, 5, 5, 6, 6, 7, 4, 6, 4, 6, 5, 5, 6, 5, 5,
#        5, 5, 6, 6, 6, 6, 6, 7, 6, 5, 6, 6, 6, 5, 6, 6, 5, 5, 5, 6, 6, 5,
#        5, 5, 5, 5, 5, 6, 6, 5, 5, 6, 6, 6, 5, 5, 5, 5, 5, 5, 6, 5, 6, 7,
#        5, 5, 6, 6, 5, 6, 7, 6, 6, 5, 5, 5, 6, 5, 5, 6, 7, 5, 6, 5, 5, 7,
#        5, 5, 7, 6, 7, 6, 5, 5, 6, 7, 6, 6, 6, 5, 5, 6, 6, 5, 6, 5, 6, 6,
#        5, 6, 5, 6, 7, 5, 5, 6, 6, 5, 5, 5, 6, 6, 6, 6, 5, 7, 4, 6, 7, 5,
#        6, 5, 6, 7, 6, 5, 7, 3, 5, 5, 6, 5, 6, 6, 5, 5, 5, 6, 5, 5, 7, 4,
# ...

# %%
# presentación de la matriz de confusión
pd.crosstab(np.array([y[0] for y in y_test.values.tolist()]), predicciones, rownames=['Actual'], colnames=['Predicciones'])
# Out:
# Predicciones  3  4    5   6   7  8
# Actual
# 3             0  0    2   0   0  0
# 4             1  3    6   1   0  0
# 5             0  1  124  42  14  0
# 6             1  1   40  87  20  2
# 7             0  0    3  22  23  1
# 8             0  0    1   3   2  0

# %%
#Analiza metrica, compara los valores reales con las predicciones
accuracy = accuracy_score(y_test,predicciones)
accuracy
# Out:
# 0.5925
